# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
toss=np.array([])
s1=np.array([])
s2=np.array([])
s3=np.array([])
i1=np.array([])

no_of_trials=100
no_of_iter=20



for exp  in range(no_of_iter):
    for i in range(no_of_trials):
        toss=np.append(toss,np.random.randint(2))

    s1=np.append(s1,np.sum(toss))
    s2=np.append(s2,(np.sum(toss))/no_of_iter)
    s3=np.append(s3,(np.sum(toss))/np.sqrt(no_of_iter))



#plt.plot(i1,toss)
#plt.show()

plt.hist(s1)
plt.show()
plt.hist(s2)
plt.show()
plt.hist(s3)
plt.show()
#print(x)

# %%
print(s1)
print(s2)
print(s3)
# Out:
# [ 3.  7. 10. 12. 14. 16. 18. 22. 23. 26. 28. 31. 35. 37. 38. 41. 42. 47.
#  49. 50.]
# [0.15 0.35 0.5  0.6  0.7  0.8  0.9  1.1  1.15 1.3  1.4  1.55 1.75 1.85
#  1.9  2.05 2.1  2.35 2.45 2.5 ]
# [ 0.67082039  1.56524758  2.23606798  2.68328157  3.13049517  3.57770876
#   4.02492236  4.91934955  5.14295635  5.81377674  6.26099034  6.93181073
#   7.82623792  8.27345152  8.49705831  9.16787871  9.39148551 10.50951949
#  10.95673309 11.18033989]

# %%
gua=np.random.uniform(-1,1,5001)
nor=np.random.normal(0,1,5001)
tri=np.random.triangular(-1,0,1,5001)

plt.subplot(1,4,1)
plt.hist(gua)
plt.show()

plt.subplot(1,4,2)
plt.hist(gua,bins=200)
plt.show()

plt.subplot(1,4,3)
plt.hist(tri,bins=200)
plt.show()
